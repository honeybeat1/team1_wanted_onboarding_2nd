# %% [markdown]
# <a href="https://colab.research.google.com/github/honeybeat1/team1_wanted_onboarding_2nd/blob/master/pandas_plot_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas의 DataFrame의 .plot으로 그래프 그리기

# %% [markdown]
# ## Reference : https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %% [markdown]
# * ‘bar’ or ‘barh’ for bar plots
# * ‘hist’ for histogram
# * ‘box’ for boxplot
# * ‘kde’ or ‘density’ for density plots
# * ‘area’ for area plots
# * ‘scatter’ for scatter plots
# * ‘hexbin’ for hexagonal bin plots
# * ‘pie’ for pie plots

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Line Plot 그리기

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot(figsize=(12,8));

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()
df.plot();

# %%
df
# Out:
#                     A          B          C          D
# 2000-01-01  -0.049100   0.473392   0.125121   1.233806
# 2000-01-02   1.549647  -0.119354   2.718358   0.997243
# 2000-01-03   1.215684  -2.120179   3.311974   1.525129
# 2000-01-04   3.527677  -0.483583   2.524457   1.715584
# 2000-01-05   2.990988  -0.670604   2.849059   1.904912
# ...               ...        ...        ...        ...
# 2002-09-22  31.466665 -19.895147 -39.562921 -28.268384
# 2002-09-23  31.514151 -21.419925 -40.092541 -27.468379
# 2002-09-24  29.852932 -22.460502 -38.926590 -27.479996
# 2002-09-25  28.185375 -22.831790 -38.192224 -28.806016
# 2002-09-26  28.771024 -23.403781 -37.691485 -27.051532
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Bar Plot 그리기

# %%
df.iloc[5]
# Out:
# A   -0.334625
# B   -0.943544
# C   -3.097529
# D   -2.987210
# Name: 2000-01-06 00:00:00, dtype: float64

# %%
df.iloc[5].plot(kind="bar");

# %%
df.iloc[5].plot(kind="barh");

# %% [markdown]
# ### Hist plot 그리기

# %%
df4 = pd.DataFrame(
    {
        "a": np.random.randn(1000) + 1,
        "b": np.random.randn(1000),
        "c": np.random.randn(1000) - 1,
     },
     columns=["a", "b", "c"],
     )
df4.plot(kind="hist", alpha=0.5)

# %%
df4
# Out:
#             a         b         c
# 0   -0.519538  0.680758 -0.029524
# 1    0.119252 -0.237650 -2.103859
# 2    0.424145  2.493157 -2.629121
# 3   -0.726405 -0.291151 -2.100862
# 4    1.549072  1.141674 -2.506389
# ..        ...       ...       ...
# 995  2.688600  0.424733 -1.810122
# 996  1.754512  0.269370 -0.474009
# 997  1.727271  0.850486 -0.053546
# 998  2.445091 -0.311326 -1.082298
# 999 -1.130737  1.506838 -0.892119
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### Box Plot 그리기

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])
df.plot(kind="box");

# %%
df
# Out:
#           A         B         C         D         E
# 0  0.200421  0.979212  0.878048  0.025027  0.841288
# 1  0.938291  0.681213  0.234641  0.324777  0.729248
# 2  0.555444  0.919689  0.643223  0.781041  0.024812
# 3  0.127096  0.180822  0.528264  0.505501  0.347989
# 4  0.259767  0.724135  0.317004  0.614096  0.704344
# 5  0.888589  0.913521  0.393681  0.346904  0.110646
# 6  0.518563  0.104558  0.113220  0.103992  0.488736
# 7  0.526816  0.663970  0.658170  0.083668  0.185289
# 8  0.059703  0.219363  0.107142  0.435254  0.476569
# 9  0.330132  0.383705  0.635938  0.759066  0.310336

# %% [markdown]
# ### Area plot 그리기

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df.plot(kind="area");

# %%
df
# Out:
#           a         b         c         d
# 0  0.562754  0.549115  0.794227  0.478421
# 1  0.483621  0.214828  0.694258  0.217035
# 2  0.888752  0.695549  0.349467  0.467324
# 3  0.098532  0.168526  0.415691  0.063821
# 4  0.372572  0.656281  0.663310  0.157152
# 5  0.378123  0.351403  0.533245  0.500093
# 6  0.563201  0.777772  0.544788  0.104895
# 7  0.409782  0.312609  0.151585  0.398040
# 8  0.806657  0.123048  0.278970  0.304823
# 9  0.406559  0.824691  0.293778  0.333352

# %% [markdown]
# ### Scatter plot 그리기

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])
df.plot(kind="scatter", x="a", y="b");

# %%
df.plot(kind="scatter", x="c", y="d");

# %%
df
# Out:
#            a         b         c         d
# 0   0.350557  0.266144  0.705640  0.544520
# 1   0.716910  0.971002  0.240803  0.086449
# 2   0.523576  0.435010  0.075211  0.328537
# 3   0.455686  0.650268  0.149825  0.896454
# 4   0.388885  0.505090  0.667926  0.620485
# 5   0.783782  0.786987  0.257579  0.412636
# 6   0.763465  0.629511  0.122570  0.490590
# 7   0.470860  0.454061  0.394049  0.759411
# 8   0.757482  0.106738  0.992943  0.929120
# 9   0.312161  0.540471  0.720658  0.485697
# 10  0.243036  0.493176  0.263344  0.876470
# 11  0.688521  0.627082  0.800607  0.384055
# 12  0.401777  0.813849  0.031488  0.286798
# 13  0.490450  0.846477  0.503420  0.876219
# 14  0.219335  0.576603  0.830695  0.401269
# 15  0.278567  0.036946  0.007321  0.707889
# 16  0.308821  0.083092  0.331027  0.675177
# 17  0.116979  0.227263  0.028755  0.712115
# 18  0.261452  0.331280  0.839846  0.223478
# 19  0.042298  0.584670  0.898468  0.498273
# 20  0.375997  0.563969  0.896212  0.762157
# ...

# %%
df.plot(kind="scatter", x="a", y="c");

# %% [markdown]
# ### Pie plot 그리기

# %%
series = pd.Series(3 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")
series.plot(kind="pie",figsize=(6, 6))

# %%
series
# Out:
# a    0.579635
# b    0.537994
# c    2.987966
# d    1.934530
# Name: series, dtype: float64

# %%
df = pd.DataFrame(
    3 * np.random.rand(4, 2), index=["a", "b", "c", "d"], columns=["x", "y"]
    )
df.plot(kind="pie", subplots=True, figsize=(8, 4));

# %%
df
# Out:
#           x         y
# a  0.816284  2.114009
# b  0.269386  1.218222
# c  1.352875  0.830232
# d  1.877230  1.690317
