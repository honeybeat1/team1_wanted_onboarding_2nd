# %% [markdown]
# # 유니콘 기업 찾기

# %% [markdown]
# ## 유니콘 기업이란
# - 기업가치 1조 이상
# - 창업한지 10년 이하인 비상장 스타트업 기업
# - 분석에 의해서 생각되는 유니콘 기업 회사 ID (최소 5개이상)
# - 유니콥스 : 유니콘(unicorn)과 시체(corpse)의 합성어로 죽은 유니콘, 즉 유니콘 기업으로 반짝 성공했다가 실패한 기업(가치를 인정 받았지만 매년 손실이 발생하여 기업가치가 거품임이 나타난 기업(파산)

# %% [markdown]
# ## 한국의 유니콘 기업
# (https://better-together.tistory.com/191 )
#
# 1. 쿠팡
#     1. 기업 가치 : 90억 달러(약 9조원)
#     2. 설립 : 2010년 8월
#     3. 등재 시점 : 2014년 5월
#     4. 주요브랜드 : 로켓배송, 로켓프레시, 쿠팡이츠, 쿠팡 플레이
#     5. 업종 : 온라인 쇼핑

# %% [markdown]
# 2.  크래프톤
#     1. 기업 가치 : 50억 달러(약 5조원)
#     2. 설립 : 2007년 3월
#     3. 등재 시점 : 2018.08
#     4. 주요 브랜드 : 테라, 베틀그라운드
#     5. 업종 : 온라인 게임

# %% [markdown]
# 3.  옐로모바일
#     1. 기업가치 : 40억달러(약 4조원)
#     2. 설립 : 2012년 8월
#     3. 등재 시점: 2014년 11월
#     4. 주요 브랜드 : 파키캐스트, 쿠차
#     5. 업종 : 모바일 커뮤니케이션

# %% [markdown]
# 4. 비바리퍼블리카
#     1.  기업가치 : 40억달러(약 4조원)
#     2. 설립 : 2013년 4월
#     3. 등재 시점: 2018년 12월
#     4. 주요 브랜드 : 토스
#     5. 업종 : 핀테크

# %% [markdown]
# 5. 위메프
#     1.  기업가치 : 40억달러(약 4조원)
#     2. 설립 : 2010년 5월
#     3. 등재 시점: 2015년 9월
#     4. 주요 브랜드 : 위메프
#     5. 업종 : 온라인 쇼핑

# %% [markdown]
# 6. 무신사
#     1.  기업가치 : 40억달러(약 4조원)
#     2. 설립 : 2012년 6월
#     3. 등재 시점: 2019년 11월
#     4. 주요 브랜드 : 무신사
#     5. 업종 : 패션커머스

# %% [markdown]
# 7. 지피클럽
#     1.  기업가치 : 40억달러(약 4조원)
#     2. 설립 : 2013년 9월
#     3. 등재 시점: 2018년 10월
#     4. 주요 브랜드 : JM 솔루션, 강블리라이프
#     5. 업종 : 화장품

# %% [markdown]
# 8. 엘앤피코스메틱
#     1.  기업가치 : 40억달러(약 4조원)
#     2. 설립 : 2009년 4월
#     3. 등재 시점: 2016년 1월
#     4. 주요 브랜드 : 메디힐
#     5. 업종 : 화장품

# %% [markdown]
# 9. 에이프로젠
#     1. 기업가치 : 40억달러(약 4조원)
#     2. 설립 : 2000년 4월
#     3. 등재 시점: 2019년 5월
#     4. 주요 브랜드 : GS071
#     5. 업종 : 바이오

# %% [markdown]
# 10. 야놀자
#     1. 기업가치 : 40억달러(약 4조원)
#     2. 설립 : 2007년 2월
#     3. 등재 시점: 2019년 6월
#     4. 주요 브랜드 : 야놀자
#     5. 업종 : 여가플랫폼

# %% [markdown]
# 11. 쏘카
#     1. 기업가치 : 40억달러(약 4조원)
#     2. 설립 : 2011년 10월
#     3. 등재 시점: 2020년 10월
#     4. 주요 브랜드 : 쏘카
#     5. 업종 : 차량공유

# %% [markdown]
# ## 1. 모듈 Import

# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline


# 전처리  
import numpy as np
import pandas as pd

# 시각화
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt

# 한글 폰트 설정
plt.rcParams['font.family'] = 'AppleGothic'

# %% [markdown]
# ## 2. 데이터 불러오기

# %%
df = pd.read_csv("./company_nps_data.csv",encoding="cp949")
df.head()
# Out:
#      회사ID      연매출액    년도   월  월별_연금보험료  월별_직원수
# 0  233757  41688077  2018   7   8912380      36
# 1  123464   1760695  2018   3    942380       5
# 2  342124   3221341  2018   7    781180       4
# 3  386420   4815584  2015  11   3795900      14
# 4  129243   9799736  2018  10  40724680     151

# %% [markdown]
# ## 3. 데이터 정보
# - 99801 회사 데이터

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99801 entries, 0 to 99800
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   회사ID      99801 non-null  int64
#  1   연매출액      99801 non-null  int64
#  2   년도        99801 non-null  int64
#  3   월         99801 non-null  int64
#  4   월별_연금보험료  99801 non-null  int64
#  5   월별_직원수    99801 non-null  int64
# dtypes: int64(6)
# memory usage: 4.6 MB

# %%
df["년도"].unique()
# Out:
# array([2018, 2015, 2016, 2017, 2019])

# %% [markdown]
# ## 4. 데이터 결측값 확인

# %%
# 결측값 없음
import missingno as msno
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
# 기업가치 1조 이상 회사만 찾기(매출액 천원단위)
company = df[df["연매출액"]>=1000000000]
company
# Out:
#          회사ID        연매출액    년도   월   월별_연금보험료  월별_직원수
# 308    419977  4334414000  2016   5  370003820    1313
# 370    381180  1323090131  2016  10   65115840     173
# 387    126606  1035707054  2018   4  342894700     937
# 456    126831  1753200162  2016   4  213087620     584
# 597    227414  4644329868  2017   9  906576960    2360
# ...       ...         ...   ...  ..        ...     ...
# 98344  420008  1489566686  2016   6  117081960     339
# 98555  294649  3447722831  2016   9  102125120     273
# 99231  420008  1301747031  2018  12  294177160     729
# 99447  420008  1301747031  2018   7  297287820     734
# 99769  126831  1753200162  2016   2  213087620     584
#
# [410 rows x 6 columns]

# %%
company["회사ID"].unique()
# Out:
# array([419977, 381180, 126606, 126831, 227414, 294649, 297874, 419998,
#        420008, 227415, 419945,     63, 126516])

# %%
df["날짜"] = df["년도"].astype(str) + "-" + df["월"].astype(str)

# %%
df["날짜"] =pd.to_datetime(df["날짜"])

# %%
df
# Out:
#          회사ID      연매출액    년도   월  월별_연금보험료  월별_직원수         날짜
# 0      233757  41688077  2018   7   8912380      36 2018-07-01
# 1      123464   1760695  2018   3    942380       5 2018-03-01
# 2      342124   3221341  2018   7    781180       4 2018-07-01
# 3      386420   4815584  2015  11   3795900      14 2015-11-01
# 4      129243   9799736  2018  10  40724680     151 2018-10-01
# ...       ...       ...   ...  ..       ...     ...        ...
# 99796  171439   4630622  2017   2   2402740      11 2017-02-01
# 99797  239388   1045021  2018  10   1428800       9 2018-10-01
# 99798  272304    181898  2018   3    392560       4 2018-03-01
# 99799  362194   2100218  2018  12    874780       3 2018-12-01
# 99800  124281    132900  2017  11    291940       5 2017-11-01
#
# [99801 rows x 7 columns]

# %% [markdown]
# ## 1조 이상 회사
# ``` 419977, 381180, 126606, 126831, 227414, 294649, 297874, 419998, 420008, 227415, 419945, 63, 126516 ```

# %% [markdown]
# ## 유니콘 기업
# - 유니콘 기업 : 63,419945,227415,420008, 294649, 227414, 126831, 381180
# - 애매 : 419998, 297874, 126606, 419977
# - No 유니콘 : 126516

# %% [markdown]
# ### 1. 419977 (연매출액 양호, 연금보험료 상승, 직원수 175명 이탈 - 애매)
# - 연매출액 : 4.325조 -> 4.15조 (조금 하락)  (4.1조)
# - 월별_연금보험료 : 380,000,000(조금씩 상승) -> 약 400,000,000
# - 월별_직원수 : 1375 -> 약1200 (점점하락)

# %%
df_419977 = df[df["회사ID"]==419977]
# df_419977

# %%
# 연매출액
sns.lineplot(data=df_419977, x=df_419977.날짜, y=df_419977.연매출액).set_title("419977 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_419977, x=df_419977.날짜, y=df_419977.월별_연금보험료).set_title("419977 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_419977, x=df_419977.날짜, y=df_419977.월별_직원수).set_title("419977 월별_직원수")
plt.xticks(rotation=45);

# %% [markdown]
# ### 2. 381180 (연매축액, 연금보험료, 직원수 모두 상승 - 유니콘 기업)
# - 연매출액 : 약 1.35조 -> 약 1.6조(꾸준히 상승세) (1.6조)
# - 월별_연금보험료 : 최소 : 61,000,000   2019년 66,000,000(2018년 5월 최소, but 9월 이후 상승)
# - 월별_직원수 : 180 -> 165.0 (2018년 5월 최소, but 9월 이후 상승)

# %%
df_381180 = df[df["회사ID"]==381180]

# %%
# 연매출액
sns.lineplot(data=df_381180, x=df_381180.날짜, y=df_381180.연매출액).set_title("381180 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_381180, x=df_381180.날짜, y=df_381180.월별_연금보험료).set_title("381180 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_381180, x=df_381180.날짜, y=df_381180.월별_직원수).set_title("381180 월별_직원수")
plt.xticks(rotation=45);

# %% [markdown]
# ### 3. 126606 (연매출액 상승, 연금보험료 상승, 직원수 비교적 감소 - 애매)
# - 연매출액 : 9400억 -> 1.04조 (상승세) (약 1조)
# - 월별_연금보험료 : 330,000,000 -> 370,000,000 (상승세)
# - 월별_직원수 : 1000 -> 970 (변동이 심하지만 2018-9월 대비 상승)

# %%
df_126606 = df[df["회사ID"]==126606]

# %%
# 연매출액
sns.lineplot(data=df_126606, x=df_126606.날짜, y=df_126606.연매출액).set_title("126606 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_126606, x=df_126606.날짜, y=df_126606.월별_연금보험료).set_title("126606 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_126606, x=df_126606.날짜, y=df_126606.월별_직원수).set_title("126606 월별_직원수")
plt.xticks(rotation=45);

# %% [markdown]
# ### 4. 126831(연매출액 상승, 연금보험료 상승, 직원수 변동 크지만 처음에 비해 유지 - 유니콘 기업 )
# - 연매출액 : 1.8조 -> 2.2조 (상승세) (2.2조)
# - 월별_연금보험료 : 215000000 -> 245000000 (상승세)
# - 월별_직원수 : 588 -> 587 (유지)

# %%
df_126831 = df[df["회사ID"]==126831]

# %%
# 연매출액
sns.lineplot(data=df_126831, x=df_126831.날짜, y=df_126831.연매출액).set_title("126831 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_126831, x=df_126831.날짜, y=df_126831.월별_연금보험료).set_title("126831 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_126831, x=df_126831.날짜, y=df_126831.월별_직원수).set_title("126831 월별_직원수")
plt.xticks(rotation=45);

# %% [markdown]
# ### 5. 227414 (연매출액, 연금보험료, 직원수 상승 - 유니콘 기업)
# - 연매출액 : 약 4조 -> 약 5조 (상승세) (5조)
# - 월별_연금보험료 : 750,000,000 -> 1,000,000,000 (상승세)
# - 월별_직원수 : 약 2150명 -> 2450명 (상승세)

# %%
df_227414 = df[df["회사ID"]==227414]

# %%
# 연매출액
sns.lineplot(data=df_227414, x=df_227414.날짜, y=df_227414.연매출액).set_title("227414 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_227414, x=df_227414.날짜, y=df_227414.월별_연금보험료).set_title("227414 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_227414, x=df_227414.날짜, y=df_227414.월별_직원수).set_title("227414 월별_직원수")
plt.xticks(rotation=45);

# %% [markdown]
# ### 6. 294649(연매출액, 연금보험료, 직원수 상승세  - 유니콘 기업)
# - 연매출액 : 3.8조 -> 약 3.4조 -> 약 4.2조 (상승세)
# - 월별_연금보험료 : 98,000,000 -> 113,000,000 (상승세)
# - 월별_직원수 : 270 -> 260 -> 약 278 (상승세)

# %%
df_294649 = df[df["회사ID"]==294649]

# %%
# 연매출액
sns.lineplot(data=df_294649, x=df_294649.날짜, y=df_294649.연매출액).set_title("294649 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_294649, x=df_294649.날짜, y=df_294649.월별_연금보험료).set_title("294649 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_294649, x=df_294649.날짜, y=df_294649.월별_직원수).set_title("294649 월별_직원수")
plt.xticks(rotation=45);

# %% [markdown]
#  ### 7. 297874(연매출액 유지, 보험료, 직원수 상승 - 유니콘 기업 애매)
#  - 연매출액 : 1조 -> 1.5조 -> 1.1조 (매출액 상승했다가 하락, 처음과 비교하면 유지)
# - 월별_연금보험료 : 6500000 -> 11000000 (상승)
# - 월별_직원수 : 31 -> 42 (상승)

# %%
df_297874 = df[df["회사ID"]==297874]

# %%
# 연매출액
sns.lineplot(data=df_297874, x=df_297874.날짜, y=df_297874.연매출액).set_title("297874 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_297874, x=df_297874.날짜, y=df_297874.월별_연금보험료).set_title("297874 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_297874, x=df_297874.날짜, y=df_297874.월별_직원수).set_title("297874 월별_직원수")
plt.xticks(rotation=45);

# %% [markdown]
# ### 8.  419998(연매출액 유지, 연금보험료 상승, 직원수 유지 - 유니콘 기업 애매)
# - 연매출액 : 3.52조 -> 약 3.58조 -> 약 3.51조 (상승했다가 하락했으나 처음과 비교했을때 유지)
# - 월별_연금보험료 : 약 280000000 -> 약 320000000 (상승)
# - 월별_직원수 : 약 788 -> 약 810 (810-820선에서 변동)

# %%
df_419998 = df[df["회사ID"]==419998]

# %%
# 연매출액
sns.lineplot(data=df_419998, x=df_419998.날짜, y=df_419998.연매출액).set_title("419998 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_419998, x=df_419998.날짜, y=df_419998.월별_연금보험료).set_title("419998 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_419998, x=df_419998.날짜, y=df_419998.월별_직원수).set_title("419998 월별_직원수")
plt.xticks(rotation=45);

# %% [markdown]
# ### 9. 420008(연매출액 하락, 연금보험료, 직원수 상승 - 연매출액 조금 하락했으나 연금보험료, 직원수 상승 기업 충분히 더 커질 수 있어보임(파산하지 않을 것 같음) -  유니콘 기업)
# - 연매출액 : 1.5조 -> 1.6조 -> 1.3조 (조금 하락)
# - 월별_연금보험료 : 125000000 -> 300000000(상승)
# - 월별_직원수 : 약 350 -> 약 700

# %%
df_420008 = df[df["회사ID"]==420008]

# %%
# 연매출액
sns.lineplot(data=df_420008, x=df_420008.날짜, y=df_420008.연매출액).set_title("420008 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_420008, x=df_420008.날짜, y=df_420008.월별_연금보험료).set_title("420008 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_420008, x=df_420008.날짜, y=df_420008.월별_직원수).set_title("420008 월별_직원수")
plt.xticks(rotation=45);

# %% [markdown]
# ### 10. 227415(연매출액 상승, 월별연금보험료 상승, 월별 직원수 처음에 비해 상대적 상승 - 유니콘 기업)
# - 연매출액 : 약 4.9조 -> 약 5.5조(상승)
# - 월별_연금보험료 : 7.75억 -> 9.25억(상승)
# - 월별_직원수 : 약 2200명 -> 2400명 -> 약 2350명(상승했다가 다시 하락)

# %%
df_227415 = df[df["회사ID"]==227415]

# %%
# 연매출액
sns.lineplot(data=df_227415, x=df_227415.날짜, y=df_227415.연매출액).set_title("227415 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_227415, x=df_227415.날짜, y=df_227415.월별_연금보험료).set_title("227415 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_227415, x=df_227415.날짜, y=df_227415.월별_직원수).set_title("227415 월별_직원수")
plt.xticks(rotation=45);

# %% [markdown]
# ### 11. 419945(연매출액 상승, 연금보험료상승, 직원수 하락했었으나 다시 상승 - 유니콘 기업 - 파산하지 않고 다시 살아나는 기업)
# - 연매출액 : 7000억 -> 약 1조(상승)
# - 월별_연금보험료 : 약 8.8억 -> 7.5억 -> 약 9.5억 (상승)
# - 월별_직원수 : 3100명 -> 2600명 -> 2900명 ( 하락했으나 다시 상승)

# %%
df_419945 = df[df["회사ID"]==419945]

# %%
# 연매출액
sns.lineplot(data=df_419945, x=df_419945.날짜, y=df_419945.연매출액).set_title("419945 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_419945, x=df_419945.날짜, y=df_419945.월별_연금보험료).set_title("419945 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_419945, x=df_419945.날짜, y=df_419945.월별_직원수).set_title("419945 월별_직원수")
plt.xticks(rotation=45);

# %% [markdown]
# ### 12. 63 (중간에 위기가 있어보이나 다시 상승하는 회사, 파산은 하지 않을 것같으 ㄴ회사 -유니콘 기업)
# - 연매출액 : 1.13조 (유지)
# - 월별_연금보험료 : 4.025억 -> 4.2억 (상승)
# - 월별_직원수 : 1005-> 약 1020 -> 995 -> 1015 (중간에 직원이 대거 이탈하였으나 다시 채용)

# %%
df_63 = df[df["회사ID"]==63]

# %%
# 연매출액
sns.lineplot(data=df_63, x=df_63.날짜, y=df_63.연매출액).set_title("63 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_63, x=df_63.날짜, y=df_63.월별_연금보험료).set_title("63 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_63, x=df_63.날짜, y=df_63.월별_직원수).set_title("63 월별_직원수")
plt.xticks(rotation=45);

# %% [markdown]
# ### 13. 126516(No- 모두 하락)
# - 연매출액 : 1조 -> 4000억
# - 월별_연금보험료 : 600000000 -> 300000000
# - 월별_직원수 : 약 1700 -> 약 700

# %%
df_126516 = df[df["회사ID"]==126516]

# %%
# 연매출액
sns.lineplot(data=df_126516, x=df_126516.날짜, y=df_126516.연매출액).set_title("126516 연매출액");
plt.xticks(rotation=45);

# %%
# 월별_연금보험료
sns.lineplot(data=df_126516, x=df_126516.날짜, y=df_126516.월별_연금보험료).set_title("126516 월별_연금보험료")
plt.xticks(rotation=45);

# %%
# 월별_직원수
sns.lineplot(data=df_126516, x=df_126516.날짜, y=df_126516.월별_직원수).set_title("126516 월별_직원수")
plt.xticks(rotation=45);
